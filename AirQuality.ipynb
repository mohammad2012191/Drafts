# %% [markdown]
# # Layer.ai Air Quality Prediction Challenge
# # By Mohamed Eltayeb & Azer Ksouri

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

from sklearn.preprocessing import LabelEncoder
from catboost import CatBoostRegressor
from sklearn.compose import TransformedTargetRegressor
from sklearn.metrics import mean_absolute_error

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None  # default='warn'
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Define Functions

# %%
#Plot the Features Importances
def plotImp(model, X , num = 30, fig_size = (60, 30)):
    feature_imp = pd.DataFrame({'Value':model.feature_importances_,'Feature':X.columns})
    plt.figure(figsize=fig_size)
    sns.set(font_scale = 5)
    sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", 
                                                        ascending=False)[0:num])
    plt.title('LightGBM Features (avg over folds)')
    plt.tight_layout()
    plt.savefig('lgbm_importances-01.png')
    plt.show()

# %%
#Label Encoder
def label_enc(train_df, test_df, features):
    lbl_enc = LabelEncoder()
    full_data = pd.concat([train_df[features], test_df[features]],axis=0)
    for col in (features):
        print(col)
        lbl_enc.fit(full_data[col].values)
        train_df[col] = lbl_enc.transform(train_df[col])
        test_df[col] = lbl_enc.transform(test_df[col])
    return train_df, test_df

# %%
#Group Time Series Split
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args

class GroupTimeSeriesSplit(_BaseKFold):
    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_size=None
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_size = max_train_size

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))
        group_test_size = n_groups // n_folds
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []
            for train_group_idx in unique_groups[:group_test_start]:
                train_array_tmp = group_dict[train_group_idx]
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)
            train_end = train_array.size
            if self.max_train_size and self.max_train_size < train_end:
                train_array = train_array[train_end -
                                          self.max_train_size:train_end]
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)
            yield [int(i) for i in train_array], [int(i) for i in test_array]

# %% [markdown]
# # Read the training and testing data

# %%
train_df = pd.read_csv("train.csv")
test_df = pd.read_csv("test.csv")

# %% [markdown]
# # Save The IDs

# %%
test_df = test_df.sort_values(['date','device']).reset_index(drop=True)
ID = test_df['ID']
test_df.drop('ID',inplace=True,axis=1)
train_df.drop('ID',inplace=True,axis=1)

# %% [markdown]
# # Add The Time Features

# %%
train_df = train_df.sort_values(['device','date']).reset_index(drop=True) 
test_df = test_df.sort_values(['device','date']).reset_index(drop=True)

for dataset in (train_df,test_df):
    dataset['date'] = pd.to_datetime(dataset['date'])
    dataset['Day'] = dataset.date.dt.day
    dataset['Month'] = dataset.date.dt.month
    dataset['Year'] = dataset.date.dt.year
    dataset['DayOfWeek'] = dataset.date.dt.dayofweek
    dataset['DayOfYear'] = dataset.date.dt.dayofyear
    dataset['Week'] = dataset.date.dt.weekofyear
    dataset.set_index('date', inplace=True)

# %% [markdown]
# # Exploratory data analysis

# %%
train_df.shape
# Out:
# (9923, 75)

# %%
test_df.shape
# Out:
# (4254, 74)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9923 entries, 2019-09-27 to 2020-08-19
# Data columns (total 75 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   device                                                    9923 non-null   object
#  1   site_latitude                                             9923 non-null   float64
#  2   site_longitude                                            9923 non-null   float64
#  3   humidity                                                  9923 non-null   float64
#  4   temp_mean                                                 9903 non-null   float64
#  5   SulphurDioxide_SO2_column_number_density                  4291 non-null   float64
#  6   SulphurDioxide_SO2_column_number_density_amf              4291 non-null   float64
#  7   SulphurDioxide_SO2_slant_column_number_density            4291 non-null   float64
#  8   SulphurDioxide_cloud_fraction                             4291 non-null   float64
#  9   SulphurDioxide_sensor_azimuth_angle                       4291 non-null   float64
#  10  SulphurDioxide_sensor_zenith_angle                        4291 non-null   float64
#  11  SulphurDioxide_solar_azimuth_angle                        4291 non-null   float64
#  12  SulphurDioxide_solar_zenith_angle                         4291 non-null   float64
#  13  SulphurDioxide_SO2_column_number_density_15km             4291 non-null   float64
#  14  CarbonMonoxide_CO_column_number_density                   5463 non-null   float64
#  15  CarbonMonoxide_H2O_column_number_density                  5463 non-null   float64
#  16  CarbonMonoxide_cloud_height                               5463 non-null   float64
#  17  CarbonMonoxide_sensor_altitude                            5463 non-null   float64
#  18  CarbonMonoxide_sensor_azimuth_angle                       5463 non-null   float64
#  19  CarbonMonoxide_sensor_zenith_angle                        5463 non-null   float64
#  20  CarbonMonoxide_solar_azimuth_angle                        5463 non-null   float64
#  21  CarbonMonoxide_solar_zenith_angle                         5463 non-null   float64
#  22  NitrogenDioxide_NO2_column_number_density                 3005 non-null   float64
#  23  NitrogenDioxide_tropospheric_NO2_column_number_density    3005 non-null   float64
#  24  NitrogenDioxide_stratospheric_NO2_column_number_density   3005 non-null   float64
#  25  NitrogenDioxide_NO2_slant_column_number_density           3005 non-null   float64
#  26  NitrogenDioxide_tropopause_pressure                       3005 non-null   float64
#  27  NitrogenDioxide_absorbing_aerosol_index                   3005 non-null   float64
#  28  NitrogenDioxide_cloud_fraction                            3005 non-null   float64
#  29  NitrogenDioxide_sensor_altitude                           3005 non-null   float64
#  30  NitrogenDioxide_sensor_azimuth_angle                      3005 non-null   float64
#  31  NitrogenDioxide_sensor_zenith_angle                       3005 non-null   float64
#  32  NitrogenDioxide_solar_azimuth_angle                       3005 non-null   float64
#  33  NitrogenDioxide_solar_zenith_angle                        3005 non-null   float64
#  34  Formaldehyde_tropospheric_HCHO_column_number_density      5277 non-null   float64
#  35  Formaldehyde_tropospheric_HCHO_column_number_density_amf  5277 non-null   float64
#  36  Formaldehyde_HCHO_slant_column_number_density             5277 non-null   float64
#  37  Formaldehyde_cloud_fraction                               5277 non-null   float64
#  38  Formaldehyde_solar_zenith_angle                           5277 non-null   float64
#  39  Formaldehyde_solar_azimuth_angle                          5277 non-null   float64
#  40  Formaldehyde_sensor_zenith_angle                          5277 non-null   float64
#  41  Formaldehyde_sensor_azimuth_angle                         5277 non-null   float64
#  42  UvAerosolIndex_absorbing_aerosol_index                    9588 non-null   float64
#  43  UvAerosolIndex_sensor_altitude                            9588 non-null   float64
#  44  UvAerosolIndex_sensor_azimuth_angle                       9588 non-null   float64
#  45  UvAerosolIndex_sensor_zenith_angle                        9588 non-null   float64
#  46  UvAerosolIndex_solar_azimuth_angle                        9588 non-null   float64
#  47  UvAerosolIndex_solar_zenith_angle                         9588 non-null   float64
#  48  Ozone_O3_column_number_density                            9387 non-null   float64
#  49  Ozone_O3_column_number_density_amf                        9387 non-null   float64
#  50  Ozone_O3_slant_column_number_density                      9387 non-null   float64
#  51  Ozone_O3_effective_temperature                            9387 non-null   float64
#  52  Ozone_cloud_fraction                                      9387 non-null   float64
#  53  Ozone_sensor_azimuth_angle                                9387 non-null   float64
#  54  Ozone_sensor_zenith_angle                                 9387 non-null   float64
#  55  Ozone_solar_azimuth_angle                                 9387 non-null   float64
#  56  Ozone_solar_zenith_angle                                  9387 non-null   float64
#  57  Cloud_cloud_fraction                                      8414 non-null   float64
#  58  Cloud_cloud_top_pressure                                  8414 non-null   float64
#  59  Cloud_cloud_top_height                                    8414 non-null   float64
#  60  Cloud_cloud_base_pressure                                 8414 non-null   float64
#  61  Cloud_cloud_base_height                                   8414 non-null   float64
#  62  Cloud_cloud_optical_depth                                 8414 non-null   float64
#  63  Cloud_surface_albedo                                      8414 non-null   float64
#  64  Cloud_sensor_azimuth_angle                                8414 non-null   float64
#  65  Cloud_sensor_zenith_angle                                 8414 non-null   float64
#  66  Cloud_solar_azimuth_angle                                 8414 non-null   float64
#  67  Cloud_solar_zenith_angle                                  8414 non-null   float64
#  68  pm2_5                                                     9923 non-null   float64
#  69  Day                                                       9923 non-null   int64
#  70  Month                                                     9923 non-null   int64
#  71  Year                                                      9923 non-null   int64
#  72  DayOfWeek                                                 9923 non-null   int64
#  73  DayOfYear                                                 9923 non-null   int64
#  74  Week                                                      9923 non-null   int64
# dtypes: float64(68), int64(6), object(1)
# memory usage: 5.8+ MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4254 entries, 2020-08-20 to 2020-10-19
# Data columns (total 74 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   device                                                    4254 non-null   object
#  1   site_latitude                                             4254 non-null   float64
#  2   site_longitude                                            4254 non-null   float64
#  3   humidity                                                  4254 non-null   float64
#  4   temp_mean                                                 4254 non-null   float64
#  5   SulphurDioxide_SO2_column_number_density                  914 non-null    float64
#  6   SulphurDioxide_SO2_column_number_density_amf              914 non-null    float64
#  7   SulphurDioxide_SO2_slant_column_number_density            914 non-null    float64
#  8   SulphurDioxide_cloud_fraction                             914 non-null    float64
#  9   SulphurDioxide_sensor_azimuth_angle                       914 non-null    float64
#  10  SulphurDioxide_sensor_zenith_angle                        914 non-null    float64
#  11  SulphurDioxide_solar_azimuth_angle                        914 non-null    float64
#  12  SulphurDioxide_solar_zenith_angle                         914 non-null    float64
#  13  SulphurDioxide_SO2_column_number_density_15km             914 non-null    float64
#  14  CarbonMonoxide_CO_column_number_density                   2102 non-null   float64
#  15  CarbonMonoxide_H2O_column_number_density                  2102 non-null   float64
#  16  CarbonMonoxide_cloud_height                               2102 non-null   float64
#  17  CarbonMonoxide_sensor_altitude                            2102 non-null   float64
#  18  CarbonMonoxide_sensor_azimuth_angle                       2102 non-null   float64
#  19  CarbonMonoxide_sensor_zenith_angle                        2102 non-null   float64
#  20  CarbonMonoxide_solar_azimuth_angle                        2102 non-null   float64
#  21  CarbonMonoxide_solar_zenith_angle                         2102 non-null   float64
#  22  NitrogenDioxide_NO2_column_number_density                 845 non-null    float64
#  23  NitrogenDioxide_tropospheric_NO2_column_number_density    845 non-null    float64
#  24  NitrogenDioxide_stratospheric_NO2_column_number_density   845 non-null    float64
#  25  NitrogenDioxide_NO2_slant_column_number_density           845 non-null    float64
#  26  NitrogenDioxide_tropopause_pressure                       845 non-null    float64
#  27  NitrogenDioxide_absorbing_aerosol_index                   845 non-null    float64
#  28  NitrogenDioxide_cloud_fraction                            845 non-null    float64
#  29  NitrogenDioxide_sensor_altitude                           845 non-null    float64
#  30  NitrogenDioxide_sensor_azimuth_angle                      845 non-null    float64
#  31  NitrogenDioxide_sensor_zenith_angle                       845 non-null    float64
#  32  NitrogenDioxide_solar_azimuth_angle                       845 non-null    float64
#  33  NitrogenDioxide_solar_zenith_angle                        845 non-null    float64
#  34  Formaldehyde_tropospheric_HCHO_column_number_density      1544 non-null   float64
#  35  Formaldehyde_tropospheric_HCHO_column_number_density_amf  1544 non-null   float64
#  36  Formaldehyde_HCHO_slant_column_number_density             1544 non-null   float64
#  37  Formaldehyde_cloud_fraction                               1544 non-null   float64
#  38  Formaldehyde_solar_zenith_angle                           1544 non-null   float64
#  39  Formaldehyde_solar_azimuth_angle                          1544 non-null   float64
#  40  Formaldehyde_sensor_zenith_angle                          1544 non-null   float64
#  41  Formaldehyde_sensor_azimuth_angle                         1544 non-null   float64
#  42  UvAerosolIndex_absorbing_aerosol_index                    4064 non-null   float64
#  43  UvAerosolIndex_sensor_altitude                            4064 non-null   float64
#  44  UvAerosolIndex_sensor_azimuth_angle                       4064 non-null   float64
#  45  UvAerosolIndex_sensor_zenith_angle                        4064 non-null   float64
#  46  UvAerosolIndex_solar_azimuth_angle                        4064 non-null   float64
#  47  UvAerosolIndex_solar_zenith_angle                         4064 non-null   float64
#  48  Ozone_O3_column_number_density                            4001 non-null   float64
#  49  Ozone_O3_column_number_density_amf                        4001 non-null   float64
#  50  Ozone_O3_slant_column_number_density                      4001 non-null   float64
#  51  Ozone_O3_effective_temperature                            4001 non-null   float64
#  52  Ozone_cloud_fraction                                      4001 non-null   float64
#  53  Ozone_sensor_azimuth_angle                                4001 non-null   float64
#  54  Ozone_sensor_zenith_angle                                 4001 non-null   float64
#  55  Ozone_solar_azimuth_angle                                 4001 non-null   float64
#  56  Ozone_solar_zenith_angle                                  4001 non-null   float64
#  57  Cloud_cloud_fraction                                      3739 non-null   float64
#  58  Cloud_cloud_top_pressure                                  3739 non-null   float64
#  59  Cloud_cloud_top_height                                    3739 non-null   float64
#  60  Cloud_cloud_base_pressure                                 3739 non-null   float64
#  61  Cloud_cloud_base_height                                   3739 non-null   float64
#  62  Cloud_cloud_optical_depth                                 3739 non-null   float64
#  63  Cloud_surface_albedo                                      3739 non-null   float64
#  64  Cloud_sensor_azimuth_angle                                3739 non-null   float64
#  65  Cloud_sensor_zenith_angle                                 3739 non-null   float64
#  66  Cloud_solar_azimuth_angle                                 3739 non-null   float64
#  67  Cloud_solar_zenith_angle                                  3739 non-null   float64
#  68  Day                                                       4254 non-null   int64
#  69  Month                                                     4254 non-null   int64
#  70  Year                                                      4254 non-null   int64
#  71  DayOfWeek                                                 4254 non-null   int64
#  72  DayOfYear                                                 4254 non-null   int64
#  73  Week                                                      4254 non-null   int64
# dtypes: float64(67), int64(6), object(1)
# memory usage: 2.4+ MB

# %%
train_df.head()
# Out:
#               device  site_latitude  site_longitude  humidity  temp_mean  \
# date
# 2019-09-27  A0WN66FH          0.286          32.578     0.877     20.760
# 2019-09-28  A0WN66FH          0.286          32.578     0.854     22.637
# 2019-09-29  A0WN66FH          0.286          32.578     0.835     22.703
# 2019-09-30  A0WN66FH          0.286          32.578     0.797     22.211
# 2019-10-01  A0WN66FH          0.286          32.578     0.817     22.160
#
#             SulphurDioxide_SO2_column_number_density  \
# date
# 2019-09-27                                       NaN
# 2019-09-28                                       NaN
# 2019-09-29                                       NaN
# 2019-09-30                                    -0.000
# 2019-10-01                                    -0.000
#
#             SulphurDioxide_SO2_column_number_density_amf  \
# date
# 2019-09-27                                           NaN
# 2019-09-28                                           NaN
# 2019-09-29                                           NaN
# 2019-09-30                                         0.955
# 2019-10-01                                         1.055
#
#             SulphurDioxide_SO2_slant_column_number_density  \
# date
# 2019-09-27                                             NaN
# 2019-09-28                                             NaN
# 2019-09-29                                             NaN
# 2019-09-30                                          -0.000
# 2019-10-01                                          -0.000
#
#             SulphurDioxide_cloud_fraction  \
# date
# 2019-09-27                            NaN
# 2019-09-28                            NaN
# 2019-09-29                            NaN
# 2019-09-30                          0.000
# 2019-10-01                          0.278
#
#             SulphurDioxide_sensor_azimuth_angle  \
# date
# 2019-09-27                                  NaN
# 2019-09-28                                  NaN
# 2019-09-29                                  NaN
# 2019-09-30                               74.431
# 2019-10-01                               72.166
#
#             SulphurDioxide_sensor_zenith_angle  \
# date
# 2019-09-27                                 NaN
# 2019-09-28                                 NaN
# 2019-09-29                                 NaN
# 2019-09-30                              35.451
# 2019-10-01                              57.408
#
#             SulphurDioxide_solar_azimuth_angle  \
# date
# 2019-09-27                                 NaN
# 2019-09-28                                 NaN
# 2019-09-29                                 NaN
# 2019-09-30                             -98.696
# 2019-10-01                            -102.351
#
#             SulphurDioxide_solar_zenith_angle  \
# date
# 2019-09-27                                NaN
# 2019-09-28                                NaN
# 2019-09-29                                NaN
# 2019-09-30                             20.667
# 2019-10-01                             16.282
#
#             SulphurDioxide_SO2_column_number_density_15km  \
# date
# 2019-09-27                                            NaN
# 2019-09-28                                            NaN
# 2019-09-29                                            NaN
# 2019-09-30                                         -0.000
# 2019-10-01                                         -0.000
#
#             CarbonMonoxide_CO_column_number_density  \
# date
# 2019-09-27                                      NaN
# 2019-09-28                                      NaN
# 2019-09-29                                      NaN
# 2019-09-30                                    0.037
# 2019-10-01                                    0.040
#
#             CarbonMonoxide_H2O_column_number_density  \
# date
# 2019-09-27                                       NaN
# 2019-09-28                                       NaN
# 2019-09-29                                       NaN
# 2019-09-30                                  2289.174
# 2019-10-01                                  2671.486
#
#             CarbonMonoxide_cloud_height  CarbonMonoxide_sensor_altitude  \
# date
# 2019-09-27                          NaN                             NaN
# 2019-09-28                          NaN                             NaN
# 2019-09-29                          NaN                             NaN
# 2019-09-30                        1.000                      829460.062
# 2019-10-01                     2951.745                      829258.688
#
#             CarbonMonoxide_sensor_azimuth_angle  \
# date
# 2019-09-27                                  NaN
# 2019-09-28                                  NaN
# 2019-09-29                                  NaN
# 2019-09-30                               72.342
# 2019-10-01                               70.480
#
#             CarbonMonoxide_sensor_zenith_angle  \
# date
# 2019-09-27                                 NaN
# 2019-09-28                                 NaN
# 2019-09-29                                 NaN
# 2019-09-30                              35.631
# 2019-10-01                              57.699
#
#             CarbonMonoxide_solar_azimuth_angle  \
# date
# 2019-09-27                                 NaN
# 2019-09-28                                 NaN
# 2019-09-29                                 NaN
# 2019-09-30                             -98.641
# 2019-10-01                            -102.360
#
#             CarbonMonoxide_solar_zenith_angle  \
# date
# 2019-09-27                                NaN
# 2019-09-28                                NaN
# 2019-09-29                                NaN
# 2019-09-30                             20.661
# 2019-10-01                             16.245
#
#             NitrogenDioxide_NO2_column_number_density  \
# date
# 2019-09-27                                        NaN
# 2019-09-28                                        NaN
# 2019-09-29                                        NaN
# 2019-09-30                                      0.000
# 2019-10-01                                        NaN
#
#             NitrogenDioxide_tropospheric_NO2_column_number_density  \
# date
# 2019-09-27                                                NaN
# 2019-09-28                                                NaN
# 2019-09-29                                                NaN
# 2019-09-30                                              0.000
# 2019-10-01                                                NaN
#
#             NitrogenDioxide_stratospheric_NO2_column_number_density  \
# date
# 2019-09-27                                                NaN
# 2019-09-28                                                NaN
# 2019-09-29                                                NaN
# 2019-09-30                                              0.000
# 2019-10-01                                                NaN
#
#             NitrogenDioxide_NO2_slant_column_number_density  \
# date
# 2019-09-27                                              NaN
# 2019-09-28                                              NaN
# 2019-09-29                                              NaN
# 2019-09-30                                            0.000
# 2019-10-01                                              NaN
#
#             NitrogenDioxide_tropopause_pressure  \
# date
# 2019-09-27                                  NaN
# 2019-09-28                                  NaN
# 2019-09-29                                  NaN
# 2019-09-30                             9580.239
# 2019-10-01                                  NaN
#
#             NitrogenDioxide_absorbing_aerosol_index  \
# date
# 2019-09-27                                      NaN
# 2019-09-28                                      NaN
# 2019-09-29                                      NaN
# 2019-09-30                                   -1.710
# 2019-10-01                                      NaN
#
#             NitrogenDioxide_cloud_fraction  NitrogenDioxide_sensor_altitude  \
# date
# 2019-09-27                             NaN                              NaN
# 2019-09-28                             NaN                              NaN
# 2019-09-29                             NaN                              NaN
# 2019-09-30                           0.033                       829478.250
# 2019-10-01                             NaN                              NaN
#
#             NitrogenDioxide_sensor_azimuth_angle  \
# date
# 2019-09-27                                   NaN
# 2019-09-28                                   NaN
# 2019-09-29                                   NaN
# 2019-09-30                                74.431
# 2019-10-01                                   NaN
#
#             NitrogenDioxide_sensor_zenith_angle  \
# date
# 2019-09-27                                  NaN
# 2019-09-28                                  NaN
# 2019-09-29                                  NaN
# 2019-09-30                               35.451
# 2019-10-01                                  NaN
#
#             NitrogenDioxide_solar_azimuth_angle  \
# date
# 2019-09-27                                  NaN
# 2019-09-28                                  NaN
# 2019-09-29                                  NaN
# 2019-09-30                              -98.696
# 2019-10-01                                  NaN
#
#             NitrogenDioxide_solar_zenith_angle  \
# date
# 2019-09-27                                 NaN
# 2019-09-28                                 NaN
# 2019-09-29                                 NaN
# 2019-09-30                              20.667
# 2019-10-01                                 NaN
#
#             Formaldehyde_tropospheric_HCHO_column_number_density  \
# date
# 2019-09-27                                                NaN
# 2019-09-28                                                NaN
# 2019-09-29                                                NaN
# 2019-09-30                                              0.000
# 2019-10-01                                              0.000
#
#             Formaldehyde_tropospheric_HCHO_column_number_density_amf  \
# date
# 2019-09-27                                                NaN
# 2019-09-28                                                NaN
# 2019-09-29                                                NaN
# 2019-09-30                                              1.113
# 2019-10-01                                              1.112
#
#             Formaldehyde_HCHO_slant_column_number_density  \
# date
# 2019-09-27                                            NaN
# 2019-09-28                                            NaN
# 2019-09-29                                            NaN
# 2019-09-30                                          0.000
# 2019-10-01                                          0.000
#
#             Formaldehyde_cloud_fraction  Formaldehyde_solar_zenith_angle  \
# date
# 2019-09-27                          NaN                              NaN
# 2019-09-28                          NaN                              NaN
# 2019-09-29                          NaN                              NaN
# 2019-09-30                        0.000                           20.667
# 2019-10-01                        0.278                           16.282
#
#             Formaldehyde_solar_azimuth_angle  \
# date
# 2019-09-27                               NaN
# 2019-09-28                               NaN
# 2019-09-29                               NaN
# 2019-09-30                           -98.696
# 2019-10-01                          -102.351
#
#             Formaldehyde_sensor_zenith_angle  \
# date
# 2019-09-27                               NaN
# 2019-09-28                               NaN
# 2019-09-29                               NaN
# 2019-09-30                            35.451
# 2019-10-01                            57.408
#
#             Formaldehyde_sensor_azimuth_angle  \
# date
# 2019-09-27                                NaN
# 2019-09-28                                NaN
# 2019-09-29                                NaN
# 2019-09-30                             74.431
# 2019-10-01                             72.166
#
#             UvAerosolIndex_absorbing_aerosol_index  \
# date
# 2019-09-27                                  -0.262
# 2019-09-28                                  -0.702
# 2019-09-29                                  -1.649
# 2019-09-30                                  -1.710
# 2019-10-01                                  -1.614
#
#             UvAerosolIndex_sensor_altitude  \
# date
# 2019-09-27                      829764.375
# 2019-09-28                      829788.938
# 2019-09-29                      829668.675
# 2019-09-30                      829478.250
# 2019-10-01                      829289.047
#
#             UvAerosolIndex_sensor_azimuth_angle  \
# date
# 2019-09-27                              -93.763
# 2019-09-28                              -99.787
# 2019-09-29                             -103.629
# 2019-09-30                               74.431
# 2019-10-01                               72.166
#
#             UvAerosolIndex_sensor_zenith_angle  \
# date
# 2019-09-27                              58.262
# 2019-09-28                              36.390
# 2019-09-29                               0.745
# 2019-09-30                              35.451
# 2019-10-01                              57.408
#
#             UvAerosolIndex_solar_azimuth_angle  \
# date
# 2019-09-27                             -93.279
# 2019-09-28                             -94.576
# 2019-09-29                             -96.198
# 2019-09-30                             -98.696
# 2019-10-01                            -102.351
#
#             UvAerosolIndex_solar_zenith_angle  Ozone_O3_column_number_density  \
# date
# 2019-09-27                             34.373                           0.115
# 2019-09-28                             29.739                           0.115
# 2019-09-29                             25.182                           0.115
# 2019-09-30                             20.667                           0.116
# 2019-10-01                             16.282                           0.117
#
#             Ozone_O3_column_number_density_amf  \
# date
# 2019-09-27                               2.997
# 2019-09-28                               2.376
# 2019-09-29                               2.105
# 2019-09-30                               2.289
# 2019-10-01                               2.839
#
#             Ozone_O3_slant_column_number_density  \
# date
# 2019-09-27                                 0.349
# 2019-09-28                                 0.276
# 2019-09-29                                 0.245
# 2019-09-30                                 0.272
# 2019-10-01                                 0.338
#
#             Ozone_O3_effective_temperature  Ozone_cloud_fraction  \
# date
# 2019-09-27                         222.859                 1.000
# 2019-09-28                         227.165                 0.451
# 2019-09-29                         220.777                 0.734
# 2019-09-30                         227.476                 0.000
# 2019-10-01                         228.514                 0.278
#
#             Ozone_sensor_azimuth_angle  Ozone_sensor_zenith_angle  \
# date
# 2019-09-27                     -93.754                     58.360
# 2019-09-28                     -99.787                     36.390
# 2019-09-29                    -103.629                      0.745
# 2019-09-30                      74.431                     35.451
# 2019-10-01                      72.166                     57.408
#
#             Ozone_solar_azimuth_angle  Ozone_solar_zenith_angle  \
# date
# 2019-09-27                    -93.277                    34.401
# 2019-09-28                    -94.576                    29.739
# 2019-09-29                    -96.198                    25.182
# 2019-09-30                    -98.696                    20.667
# 2019-10-01                   -102.351                    16.282
#
#             Cloud_cloud_fraction  Cloud_cloud_top_pressure  \
# date
# 2019-09-27                 1.000                 36288.625
# 2019-09-28                 0.451                 57830.965
# 2019-09-29                 0.892                 17882.896
# 2019-09-30                   NaN                       NaN
# 2019-10-01                 0.278                 64740.239
#
#             Cloud_cloud_top_height  Cloud_cloud_base_pressure  \
# date
# 2019-09-27                8233.294                  41519.246
# 2019-09-28                4675.087                  65457.598
# 2019-09-29               12995.496                  20972.160
# 2019-09-30                     NaN                        NaN
# 2019-10-01                3765.821                  73150.386
#
#             Cloud_cloud_base_height  Cloud_cloud_optical_depth  \
# date
# 2019-09-27                 7233.293                     56.773
# 2019-09-28                 3675.087                      7.490
# 2019-09-29                11995.496                      7.945
# 2019-09-30                      NaN                        NaN
# 2019-10-01                 2765.821                      4.407
#
#             Cloud_surface_albedo  Cloud_sensor_azimuth_angle  \
# date
# 2019-09-27                 0.249                     -93.773
# 2019-09-28                 0.278                     -99.787
# 2019-09-29                 0.224                    -103.768
# 2019-09-30                   NaN                         NaN
# 2019-10-01                 0.262                      72.162
#
#             Cloud_sensor_zenith_angle  Cloud_solar_azimuth_angle  \
# date
# 2019-09-27                     58.146                    -93.282
# 2019-09-28                     36.391                    -94.576
# 2019-09-29                      0.684                    -96.269
# 2019-09-30                        NaN                        NaN
# 2019-10-01                     57.407                   -102.423
#
#             Cloud_solar_zenith_angle  pm2_5  Day  Month  Year  DayOfWeek  \
# date
# 2019-09-27                    34.339 72.836   27      9  2019          4
# 2019-09-28                    29.739 39.781   28      9  2019          5
# 2019-09-29                    25.174 57.602   29      9  2019          6
# 2019-09-30                       NaN 25.907   30      9  2019          0
# 2019-10-01                    16.283 48.140    1     10  2019          1
#
#             DayOfYear  Week
# date
# 2019-09-27        270    39
# 2019-09-28        271    39
# 2019-09-29        272    39
# 2019-09-30        273    40
# 2019-10-01        274    40

# %%
test_df.head()
# Out:
#               device  site_latitude  site_longitude  humidity  temp_mean  \
# date
# 2020-08-20  A0WN66FH          0.286          32.578     0.792     23.349
# 2020-08-21  A0WN66FH          0.286          32.578     0.790     22.989
# 2020-08-22  A0WN66FH          0.286          32.578     0.827     22.844
# 2020-08-23  A0WN66FH          0.286          32.578     0.822     22.601
# 2020-08-24  A0WN66FH          0.286          32.578     0.894     20.560
#
#             SulphurDioxide_SO2_column_number_density  \
# date
# 2020-08-20                                     0.000
# 2020-08-21                                       NaN
# 2020-08-22                                       NaN
# 2020-08-23                                     0.000
# 2020-08-24                                       NaN
#
#             SulphurDioxide_SO2_column_number_density_amf  \
# date
# 2020-08-20                                         0.858
# 2020-08-21                                           NaN
# 2020-08-22                                           NaN
# 2020-08-23                                         0.438
# 2020-08-24                                           NaN
#
#             SulphurDioxide_SO2_slant_column_number_density  \
# date
# 2020-08-20                                           0.000
# 2020-08-21                                             NaN
# 2020-08-22                                             NaN
# 2020-08-23                                           0.000
# 2020-08-24                                             NaN
#
#             SulphurDioxide_cloud_fraction  \
# date
# 2020-08-20                          0.210
# 2020-08-21                            NaN
# 2020-08-22                            NaN
# 2020-08-23                          0.174
# 2020-08-24                            NaN
#
#             SulphurDioxide_sensor_azimuth_angle  \
# date
# 2020-08-20                               75.368
# 2020-08-21                                  NaN
# 2020-08-22                                  NaN
# 2020-08-23                              -98.348
# 2020-08-24                                  NaN
#
#             SulphurDioxide_sensor_zenith_angle  \
# date
# 2020-08-20                              24.837
# 2020-08-21                                 NaN
# 2020-08-22                                 NaN
# 2020-08-23                              52.177
# 2020-08-24                                 NaN
#
#             SulphurDioxide_solar_azimuth_angle  \
# date
# 2020-08-20                             -56.408
# 2020-08-21                                 NaN
# 2020-08-22                                 NaN
# 2020-08-23                             -68.687
# 2020-08-24                                 NaN
#
#             SulphurDioxide_solar_zenith_angle  \
# date
# 2020-08-20                             21.970
# 2020-08-21                                NaN
# 2020-08-22                                NaN
# 2020-08-23                             31.503
# 2020-08-24                                NaN
#
#             SulphurDioxide_SO2_column_number_density_15km  \
# date
# 2020-08-20                                          0.000
# 2020-08-21                                            NaN
# 2020-08-22                                            NaN
# 2020-08-23                                          0.000
# 2020-08-24                                            NaN
#
#             CarbonMonoxide_CO_column_number_density  \
# date
# 2020-08-20                                    0.048
# 2020-08-21                                    0.029
# 2020-08-22                                      NaN
# 2020-08-23                                    0.037
# 2020-08-24                                      NaN
#
#             CarbonMonoxide_H2O_column_number_density  \
# date
# 2020-08-20                                  2494.005
# 2020-08-21                                  3169.188
# 2020-08-22                                       NaN
# 2020-08-23                                  2317.106
# 2020-08-24                                       NaN
#
#             CarbonMonoxide_cloud_height  CarbonMonoxide_sensor_altitude  \
# date
# 2020-08-20                     1959.492                      829581.750
# 2020-08-21                     4631.772                      829368.000
# 2020-08-22                          NaN                             NaN
# 2020-08-23                      910.123                      829847.875
# 2020-08-24                          NaN                             NaN
#
#             CarbonMonoxide_sensor_azimuth_angle  \
# date
# 2020-08-20                               72.628
# 2020-08-21                               71.077
# 2020-08-22                                  NaN
# 2020-08-23                              -96.662
# 2020-08-24                                  NaN
#
#             CarbonMonoxide_sensor_zenith_angle  \
# date
# 2020-08-20                              25.045
# 2020-08-21                              51.419
# 2020-08-22                                 NaN
# 2020-08-23                              52.100
# 2020-08-24                                 NaN
#
#             CarbonMonoxide_solar_azimuth_angle  \
# date
# 2020-08-20                             -56.395
# 2020-08-21                             -49.853
# 2020-08-22                                 NaN
# 2020-08-23                             -68.696
# 2020-08-24                                 NaN
#
#             CarbonMonoxide_solar_zenith_angle  \
# date
# 2020-08-20                             21.961
# 2020-08-21                             18.125
# 2020-08-22                                NaN
# 2020-08-23                             31.472
# 2020-08-24                                NaN
#
#             NitrogenDioxide_NO2_column_number_density  \
# date
# 2020-08-20                                        NaN
# 2020-08-21                                        NaN
# 2020-08-22                                        NaN
# 2020-08-23                                      0.000
# 2020-08-24                                        NaN
#
#             NitrogenDioxide_tropospheric_NO2_column_number_density  \
# date
# 2020-08-20                                                NaN
# 2020-08-21                                                NaN
# 2020-08-22                                                NaN
# 2020-08-23                                              0.000
# 2020-08-24                                                NaN
#
#             NitrogenDioxide_stratospheric_NO2_column_number_density  \
# date
# 2020-08-20                                                NaN
# 2020-08-21                                                NaN
# 2020-08-22                                                NaN
# 2020-08-23                                              0.000
# 2020-08-24                                                NaN
#
#             NitrogenDioxide_NO2_slant_column_number_density  \
# date
# 2020-08-20                                              NaN
# 2020-08-21                                              NaN
# 2020-08-22                                              NaN
# 2020-08-23                                            0.000
# 2020-08-24                                              NaN
#
#             NitrogenDioxide_tropopause_pressure  \
# date
# 2020-08-20                                  NaN
# 2020-08-21                                  NaN
# 2020-08-22                                  NaN
# 2020-08-23                             8613.727
# 2020-08-24                                  NaN
#
#             NitrogenDioxide_absorbing_aerosol_index  \
# date
# 2020-08-20                                      NaN
# 2020-08-21                                      NaN
# 2020-08-22                                      NaN
# 2020-08-23                                   -1.824
# 2020-08-24                                      NaN
#
#             NitrogenDioxide_cloud_fraction  NitrogenDioxide_sensor_altitude  \
# date
# 2020-08-20                             NaN                              NaN
# 2020-08-21                             NaN                              NaN
# 2020-08-22                             NaN                              NaN
# 2020-08-23                           0.081                       829885.438
# 2020-08-24                             NaN                              NaN
#
#             NitrogenDioxide_sensor_azimuth_angle  \
# date
# 2020-08-20                                   NaN
# 2020-08-21                                   NaN
# 2020-08-22                                   NaN
# 2020-08-23                               -98.348
# 2020-08-24                                   NaN
#
#             NitrogenDioxide_sensor_zenith_angle  \
# date
# 2020-08-20                                  NaN
# 2020-08-21                                  NaN
# 2020-08-22                                  NaN
# 2020-08-23                               52.177
# 2020-08-24                                  NaN
#
#             NitrogenDioxide_solar_azimuth_angle  \
# date
# 2020-08-20                                  NaN
# 2020-08-21                                  NaN
# 2020-08-22                                  NaN
# 2020-08-23                              -68.687
# 2020-08-24                                  NaN
#
#             NitrogenDioxide_solar_zenith_angle  \
# date
# 2020-08-20                                 NaN
# 2020-08-21                                 NaN
# 2020-08-22                                 NaN
# 2020-08-23                              31.503
# 2020-08-24                                 NaN
#
#             Formaldehyde_tropospheric_HCHO_column_number_density  \
# date
# 2020-08-20                                              0.000
# 2020-08-21                                              0.000
# 2020-08-22                                                NaN
# 2020-08-23                                              0.000
# 2020-08-24                                                NaN
#
#             Formaldehyde_tropospheric_HCHO_column_number_density_amf  \
# date
# 2020-08-20                                              1.083
# 2020-08-21                                              0.896
# 2020-08-22                                                NaN
# 2020-08-23                                              0.970
# 2020-08-24                                                NaN
#
#             Formaldehyde_HCHO_slant_column_number_density  \
# date
# 2020-08-20                                          0.000
# 2020-08-21                                          0.000
# 2020-08-22                                            NaN
# 2020-08-23                                          0.000
# 2020-08-24                                            NaN
#
#             Formaldehyde_cloud_fraction  Formaldehyde_solar_zenith_angle  \
# date
# 2020-08-20                        0.210                           21.970
# 2020-08-21                        0.465                           18.107
# 2020-08-22                          NaN                              NaN
# 2020-08-23                        0.174                           31.503
# 2020-08-24                          NaN                              NaN
#
#             Formaldehyde_solar_azimuth_angle  \
# date
# 2020-08-20                           -56.408
# 2020-08-21                           -49.660
# 2020-08-22                               NaN
# 2020-08-23                           -68.687
# 2020-08-24                               NaN
#
#             Formaldehyde_sensor_zenith_angle  \
# date
# 2020-08-20                            24.837
# 2020-08-21                            51.518
# 2020-08-22                               NaN
# 2020-08-23                            52.177
# 2020-08-24                               NaN
#
#             Formaldehyde_sensor_azimuth_angle  \
# date
# 2020-08-20                             75.368
# 2020-08-21                             72.781
# 2020-08-22                                NaN
# 2020-08-23                            -98.348
# 2020-08-24                                NaN
#
#             UvAerosolIndex_absorbing_aerosol_index  \
# date
# 2020-08-20                                  -2.071
# 2020-08-21                                  -2.773
# 2020-08-22                                     NaN
# 2020-08-23                                  -1.824
# 2020-08-24                                  -0.926
#
#             UvAerosolIndex_sensor_altitude  \
# date
# 2020-08-20                      829601.562
# 2020-08-21                      829396.375
# 2020-08-22                             NaN
# 2020-08-23                      829885.438
# 2020-08-24                      829800.875
#
#             UvAerosolIndex_sensor_azimuth_angle  \
# date
# 2020-08-20                               75.368
# 2020-08-21                               72.781
# 2020-08-22                                  NaN
# 2020-08-23                              -98.348
# 2020-08-24                             -100.719
#
#             UvAerosolIndex_sensor_zenith_angle  \
# date
# 2020-08-20                              24.837
# 2020-08-21                              51.518
# 2020-08-22                                 NaN
# 2020-08-23                              52.177
# 2020-08-24                              26.056
#
#             UvAerosolIndex_solar_azimuth_angle  \
# date
# 2020-08-20                             -56.408
# 2020-08-21                             -49.660
# 2020-08-22                                 NaN
# 2020-08-23                             -68.687
# 2020-08-24                             -66.197
#
#             UvAerosolIndex_solar_zenith_angle  Ozone_O3_column_number_density  \
# date
# 2020-08-20                             21.970                           0.123
# 2020-08-21                             18.107                           0.120
# 2020-08-22                                NaN                             NaN
# 2020-08-23                             31.503                           0.121
# 2020-08-24                             27.100                           0.124
#
#             Ozone_O3_column_number_density_amf  \
# date
# 2020-08-20                               2.201
# 2020-08-21                               2.639
# 2020-08-22                                 NaN
# 2020-08-23                               2.760
# 2020-08-24                               2.257
#
#             Ozone_O3_slant_column_number_density  \
# date
# 2020-08-20                                 0.275
# 2020-08-21                                 0.322
# 2020-08-22                                   NaN
# 2020-08-23                                 0.340
# 2020-08-24                                 0.285
#
#             Ozone_O3_effective_temperature  Ozone_cloud_fraction  \
# date
# 2020-08-20                         234.362                 0.210
# 2020-08-21                         224.725                 0.466
# 2020-08-22                             NaN                   NaN
# 2020-08-23                         233.692                 0.174
# 2020-08-24                         228.580                 1.000
#
#             Ozone_sensor_azimuth_angle  Ozone_sensor_zenith_angle  \
# date
# 2020-08-20                      75.368                     24.837
# 2020-08-21                      72.781                     51.518
# 2020-08-22                         NaN                        NaN
# 2020-08-23                     -98.348                     52.177
# 2020-08-24                    -100.719                     26.056
#
#             Ozone_solar_azimuth_angle  Ozone_solar_zenith_angle  \
# date
# 2020-08-20                    -56.408                    21.970
# 2020-08-21                    -49.660                    18.107
# 2020-08-22                        NaN                       NaN
# 2020-08-23                    -68.687                    31.503
# 2020-08-24                    -66.197                    27.100
#
#             Cloud_cloud_fraction  Cloud_cloud_top_pressure  \
# date
# 2020-08-20                 0.211                 66601.727
# 2020-08-21                 0.465                 41635.555
# 2020-08-22                   NaN                       NaN
# 2020-08-23                   NaN                       NaN
# 2020-08-24                 1.000                 45908.110
#
#             Cloud_cloud_top_height  Cloud_cloud_base_pressure  \
# date
# 2020-08-20                3553.709                  75593.211
# 2020-08-21                7425.758                  47216.414
# 2020-08-22                     NaN                        NaN
# 2020-08-23                     NaN                        NaN
# 2020-08-24                6630.184                  51949.321
#
#             Cloud_cloud_base_height  Cloud_cloud_optical_depth  \
# date
# 2020-08-20                 2553.709                      3.097
# 2020-08-21                 6425.758                      3.796
# 2020-08-22                      NaN                        NaN
# 2020-08-23                      NaN                        NaN
# 2020-08-24                 5630.184                     17.573
#
#             Cloud_surface_albedo  Cloud_sensor_azimuth_angle  \
# date
# 2020-08-20                 0.226                      75.368
# 2020-08-21                 0.246                      72.781
# 2020-08-22                   NaN                         NaN
# 2020-08-23                   NaN                         NaN
# 2020-08-24                 0.259                    -100.719
#
#             Cloud_sensor_zenith_angle  Cloud_solar_azimuth_angle  \
# date
# 2020-08-20                     24.837                    -56.408
# 2020-08-21                     51.518                    -49.660
# 2020-08-22                        NaN                        NaN
# 2020-08-23                        NaN                        NaN
# 2020-08-24                     26.056                    -66.197
#
#             Cloud_solar_zenith_angle  Day  Month  Year  DayOfWeek  DayOfYear  \
# date
# 2020-08-20                    21.970   20      8  2020          3        233
# 2020-08-21                    18.107   21      8  2020          4        234
# 2020-08-22                       NaN   22      8  2020          5        235
# 2020-08-23                       NaN   23      8  2020          6        236
# 2020-08-24                    27.100   24      8  2020          0        237
#
#             Week
# date
# 2020-08-20    34
# 2020-08-21    34
# 2020-08-22    34
# 2020-08-23    34
# 2020-08-24    35

# %%
train_df.describe()
# Out:
#        site_latitude  site_longitude  humidity  temp_mean  \
# count       9923.000        9923.000  9923.000   9903.000
# mean           0.243          32.472     0.791     21.571
# std            0.332           0.546     0.158      4.061
# min           -1.245          29.989     0.000      0.000
# 25%            0.289          32.554     0.771     21.233
# 50%            0.315          32.590     0.823     22.272
# 75%            0.355          32.618     0.869     23.314
# max            0.391          32.753     1.000     29.735
#
#        SulphurDioxide_SO2_column_number_density  \
# count                                  4291.000
# mean                                      0.000
# std                                       0.000
# min                                      -0.001
# 25%                                      -0.000
# 50%                                       0.000
# 75%                                       0.000
# max                                       0.002
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# count                                      4291.000
# mean                                          0.791
# std                                           0.198
# min                                           0.346
# 25%                                           0.659
# 50%                                           0.785
# 75%                                           0.907
# max                                           1.633
#
#        SulphurDioxide_SO2_slant_column_number_density  \
# count                                        4291.000
# mean                                            0.000
# std                                             0.000
# min                                            -0.001
# 25%                                            -0.000
# 50%                                             0.000
# 75%                                             0.000
# max                                             0.002
#
#        SulphurDioxide_cloud_fraction  SulphurDioxide_sensor_azimuth_angle  \
# count                       4291.000                             4291.000
# mean                           0.147                              -17.585
# std                            0.086                               86.752
# min                            0.000                             -105.714
# 25%                            0.084                              -99.641
# 50%                            0.148                              -97.302
# 75%                            0.217                               73.653
# max                            0.300                               84.743
#
#        SulphurDioxide_sensor_zenith_angle  SulphurDioxide_solar_azimuth_angle  \
# count                            4291.000                            4291.000
# mean                               37.886                             -86.495
# std                                19.323                              39.627
# min                                 0.101                            -159.899
# 25%                                22.521                            -126.766
# 50%                                42.489                             -81.917
# 75%                                55.985                             -49.346
# max                                66.025                             -20.703
#
#        SulphurDioxide_solar_zenith_angle  \
# count                           4291.000
# mean                              28.039
# std                                6.474
# min                                9.757
# 25%                               23.982
# 50%                               28.463
# 75%                               32.450
# max                               41.397
#
#        SulphurDioxide_SO2_column_number_density_15km  \
# count                                       4291.000
# mean                                           0.000
# std                                            0.000
# min                                           -0.000
# 25%                                           -0.000
# 50%                                            0.000
# 75%                                            0.000
# max                                            0.001
#
#        CarbonMonoxide_CO_column_number_density  \
# count                                 5463.000
# mean                                     0.035
# std                                      0.006
# min                                      0.019
# 25%                                      0.031
# 50%                                      0.033
# 75%                                      0.038
# max                                      0.070
#
#        CarbonMonoxide_H2O_column_number_density  CarbonMonoxide_cloud_height  \
# count                                  5463.000                     5463.000
# mean                                   2704.027                     2327.034
# std                                    1118.013                     1392.642
# min                                     790.617                     -200.152
# 25%                                    2143.695                     1225.931
# 50%                                    2468.993                     2324.655
# 75%                                    2857.763                     3442.470
# max                                   12919.685                     4989.290
#
#        CarbonMonoxide_sensor_altitude  CarbonMonoxide_sensor_azimuth_angle  \
# count                        5463.000                             5463.000
# mean                       829629.139                              -14.789
# std                           203.984                               83.050
# min                        829145.500                              -98.192
# 25%                        829466.250                              -97.111
# 50%                        829671.431                              -74.327
# 75%                        829796.688                               71.178
# max                        830182.375                               72.691
#
#        CarbonMonoxide_sensor_zenith_angle  CarbonMonoxide_solar_azimuth_angle  \
# count                            5463.000                            5463.000
# mean                               37.209                             -85.284
# std                                18.494                              39.856
# min                                 1.108                            -157.293
# 25%                                22.743                            -126.567
# 50%                                38.737                             -80.819
# 75%                                53.457                             -47.585
# max                                64.558                             -23.272
#
#        CarbonMonoxide_solar_zenith_angle  \
# count                           5463.000
# mean                              28.004
# std                                6.370
# min                                9.831
# 25%                               24.030
# 50%                               28.298
# 75%                               32.549
# max                               41.660
#
#        NitrogenDioxide_NO2_column_number_density  \
# count                                   3005.000
# mean                                       0.000
# std                                        0.000
# min                                       -0.000
# 25%                                        0.000
# 50%                                        0.000
# 75%                                        0.000
# max                                        0.000
#
#        NitrogenDioxide_tropospheric_NO2_column_number_density  \
# count                                           3005.000
# mean                                               0.000
# std                                                0.000
# min                                               -0.000
# 25%                                                0.000
# 50%                                                0.000
# 75%                                                0.000
# max                                                0.000
#
#        NitrogenDioxide_stratospheric_NO2_column_number_density  \
# count                                           3005.000
# mean                                               0.000
# std                                                0.000
# min                                                0.000
# 25%                                                0.000
# 50%                                                0.000
# 75%                                                0.000
# max                                                0.000
#
#        NitrogenDioxide_NO2_slant_column_number_density  \
# count                                         3005.000
# mean                                             0.000
# std                                              0.000
# min                                              0.000
# 25%                                              0.000
# 50%                                              0.000
# 75%                                              0.000
# max                                              0.000
#
#        NitrogenDioxide_tropopause_pressure  \
# count                             3005.000
# mean                              8669.070
# std                                828.532
# min                               7311.869
# 25%                               8613.726
# 50%                               8613.738
# 75%                               8613.768
# max                              13020.412
#
#        NitrogenDioxide_absorbing_aerosol_index  \
# count                                 3005.000
# mean                                    -1.651
# std                                      0.501
# min                                     -3.369
# 25%                                     -2.008
# 50%                                     -1.665
# 75%                                     -1.302
# max                                      0.105
#
#        NitrogenDioxide_cloud_fraction  NitrogenDioxide_sensor_altitude  \
# count                        3005.000                         3005.000
# mean                            0.088                       829664.405
# std                             0.049                          201.689
# min                             0.000                       829180.062
# 25%                             0.054                       829523.250
# 50%                             0.083                       829700.938
# 75%                             0.115                       829835.063
# max                             0.486                       830204.733
#
#        NitrogenDioxide_sensor_azimuth_angle  \
# count                              3005.000
# mean                                -20.506
# std                                  86.661
# min                                -105.714
# 25%                                 -99.694
# 50%                                 -97.340
# 75%                                  73.678
# max                                  84.743
#
#        NitrogenDioxide_sensor_zenith_angle  \
# count                             3005.000
# mean                                36.694
# std                                 19.328
# min                                  0.101
# 25%                                 22.207
# 50%                                 38.214
# 75%                                 53.193
# max                                 66.236
#
#        NitrogenDioxide_solar_azimuth_angle  \
# count                             3005.000
# mean                               -83.369
# std                                 40.297
# min                               -157.751
# 25%                               -125.381
# 50%                                -75.658
# 75%                                -46.966
# max                                -20.703
#
#        NitrogenDioxide_solar_zenith_angle  \
# count                            3005.000
# mean                               28.408
# std                                 6.216
# min                                 9.757
# 25%                                24.876
# 50%                                28.548
# 75%                                32.821
# max                                41.397
#
#        Formaldehyde_tropospheric_HCHO_column_number_density  \
# count                                           5277.000
# mean                                               0.000
# std                                                0.000
# min                                               -0.001
# 25%                                                0.000
# 50%                                                0.000
# 75%                                                0.000
# max                                                0.001
#
#        Formaldehyde_tropospheric_HCHO_column_number_density_amf  \
# count                                           5277.000
# mean                                               1.092
# std                                                0.294
# min                                                0.372
# 25%                                                0.919
# 50%                                                1.036
# 75%                                                1.189
# max                                                2.363
#
#        Formaldehyde_HCHO_slant_column_number_density  \
# count                                       5277.000
# mean                                           0.000
# std                                            0.000
# min                                           -0.001
# 25%                                           -0.000
# 50%                                            0.000
# 75%                                            0.000
# max                                            0.001
#
#        Formaldehyde_cloud_fraction  Formaldehyde_solar_zenith_angle  \
# count                     5277.000                         5277.000
# mean                         0.198                           28.061
# std                          0.125                            6.628
# min                          0.000                            8.703
# 25%                          0.104                           24.005
# 50%                          0.187                           28.481
# 75%                          0.292                           32.517
# max                          0.551                           41.410
#
#        Formaldehyde_solar_azimuth_angle  Formaldehyde_sensor_zenith_angle  \
# count                          5277.000                          5277.000
# mean                            -86.659                            39.514
# std                              39.749                            19.145
# min                            -160.285                             0.101
# 25%                            -126.987                            23.388
# 50%                             -82.303                            43.115
# 75%                             -50.265                            56.693
# max                             -20.703                            66.025
#
#        Formaldehyde_sensor_azimuth_angle  \
# count                           5277.000
# mean                             -17.736
# std                               86.588
# min                             -106.860
# 25%                              -99.610
# 50%                              -97.293
# 75%                               73.619
# max                               84.743
#
#        UvAerosolIndex_absorbing_aerosol_index  UvAerosolIndex_sensor_altitude  \
# count                                9588.000                        9588.000
# mean                                   -1.407                      829639.713
# std                                     0.700                         229.328
# min                                    -6.439                      829156.687
# 25%                                    -1.887                      829442.784
# 50%                                    -1.421                      829691.375
# 75%                                    -0.944                      829830.449
# max                                     1.012                      830238.569
#
#        UvAerosolIndex_sensor_azimuth_angle  \
# count                             9588.000
# mean                               -15.620
# std                                 86.605
# min                               -106.860
# 25%                                -99.625
# 50%                                -97.284
# 75%                                 73.527
# max                                 84.792
#
#        UvAerosolIndex_sensor_zenith_angle  UvAerosolIndex_solar_azimuth_angle  \
# count                            9588.000                            9588.000
# mean                               40.118                             -86.777
# std                                19.412                              40.278
# min                                 0.101                            -160.321
# 25%                                24.257                            -126.149
# 50%                                43.742                             -85.028
# 75%                                57.373                             -49.749
# max                                66.449                             -20.657
#
#        UvAerosolIndex_solar_zenith_angle  Ozone_O3_column_number_density  \
# count                           9588.000                        9387.000
# mean                              27.720                           0.116
# std                                6.855                           0.004
# min                                8.213                           0.106
# 25%                               23.300                           0.113
# 50%                               28.022                           0.116
# 75%                               32.732                           0.118
# max                               41.993                           0.126
#
#        Ozone_O3_column_number_density_amf  \
# count                            9387.000
# mean                                2.588
# std                                 0.398
# min                                 2.039
# 25%                                 2.229
# 50%                                 2.480
# 75%                                 2.871
# max                                 3.548
#
#        Ozone_O3_slant_column_number_density  Ozone_O3_effective_temperature  \
# count                              9387.000                        9387.000
# mean                                  0.304                         228.463
# std                                   0.047                           3.997
# min                                   0.227                         187.585
# 25%                                   0.263                         226.204
# 50%                                   0.293                         228.547
# 75%                                   0.342                         230.909
# max                                   0.429                         245.794
#
#        Ozone_cloud_fraction  Ozone_sensor_azimuth_angle  \
# count              9387.000                    9387.000
# mean                  0.455                     -17.495
# std                   0.339                      86.581
# min                   0.000                    -106.860
# 25%                   0.163                     -99.636
# 50%                   0.359                     -97.296
# 75%                   0.763                      73.583
# max                   1.000                      84.792
#
#        Ozone_sensor_zenith_angle  Ozone_solar_azimuth_angle  \
# count                   9387.000                   9387.000
# mean                      39.555                    -87.249
# std                       19.230                     39.759
# min                        0.101                   -160.285
# 25%                       23.967                   -126.100
# 50%                       43.116                    -85.815
# 75%                       56.693                    -50.359
# max                       66.239                    -20.703
#
#        Ozone_solar_zenith_angle  Cloud_cloud_fraction  \
# count                  9387.000              8414.000
# mean                     27.856                 0.480
# std                       6.842                 0.333
# min                       8.389                 0.000
# 25%                      23.631                 0.187
# 50%                      28.337                 0.384
# 75%                      32.774                 0.800
# max                      41.993                 1.000
#
#        Cloud_cloud_top_pressure  Cloud_cloud_top_height  \
# count                  8414.000                8414.000
# mean                  50048.337                6334.871
# std                   18886.902                3172.279
# min                   12711.389                1150.150
# 25%                   34430.057                3948.410
# 50%                   50417.750                5768.341
# 75%                   63413.425                8665.130
# max                   88330.359               15000.000
#
#        Cloud_cloud_base_pressure  Cloud_cloud_base_height  \
# count                   8414.000                 8414.000
# mean                   56017.988                 5405.379
# std                    19694.712                 3073.160
# min                    15003.535                 1150.150
# 25%                    39480.238                 2952.134
# 50%                    57283.977                 4768.781
# 75%                    71602.270                 7665.130
# max                    88513.484                14000.000
#
#        Cloud_cloud_optical_depth  Cloud_surface_albedo  \
# count                   8414.000              8414.000
# mean                      17.944                 0.269
# std                       33.709                 0.052
# min                        1.250                 0.012
# 25%                        4.791                 0.240
# 50%                        6.775                 0.268
# 75%                       14.080                 0.295
# max                      250.000                 1.000
#
#        Cloud_sensor_azimuth_angle  Cloud_sensor_zenith_angle  \
# count                    8414.000                   8414.000
# mean                      -17.784                     40.690
# std                        86.454                     19.074
# min                      -106.727                      0.101
# 25%                       -99.613                     26.535
# 50%                       -97.295                     45.017
# 75%                        72.933                     57.407
# max                        84.802                     66.234
#
#        Cloud_solar_azimuth_angle  Cloud_solar_zenith_angle    pm2_5      Day  \
# count                   8414.000                  8414.000 9923.000 9923.000
# mean                     -86.994                    27.792   57.107   15.551
# std                       40.092                     6.906   27.483    8.762
# min                     -160.285                     8.387    1.160    1.000
# 25%                     -126.529                    23.377   38.028    8.000
# 50%                      -85.783                    28.024   51.930   15.000
# 75%                      -50.007                    32.795   72.033   23.000
# max                      -20.703                    41.993  440.920   31.000
#
#          Month     Year  DayOfWeek  DayOfYear     Week
# count 9923.000 9923.000   9923.000   9923.000 9923.000
# mean     6.228 2019.692      2.984    174.242   25.334
# std      3.381    0.462      1.994    102.926   14.632
# min      1.000 2019.000      0.000      1.000    1.000
# 25%      3.000 2019.000      1.000     87.000   13.000
# 50%      6.000 2020.000      3.000    170.000   25.000
# 75%      9.000 2020.000      5.000    263.000   37.000
# max     12.000 2020.000      6.000    365.000   52.000

# %%
test_df.describe()

# %%
#The cardinality of each catgorical feature (Training)
cat_cols = train_df.columns
for col in cat_cols:
    print(col, train_df[col].nunique())

# %%
#The cardinality of each catgorical feature (Testing)
cat_cols = test_df.columns
for col in cat_cols:
    print(col, test_df[col].nunique())

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # Missing Data

# %%
#missing data percentage (Training)
total = train_df.isnull().sum().sort_values(ascending=False)
percent_1 = train_df.isnull().sum()/train_df.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data.head(60)

# %%
#missing data percentage (Testing)
total = test_df.isnull().sum().sort_values(ascending=False)
percent_1 = test_df.isnull().sum()/test_df.isnull().count()*100
percent_2 = (round(percent_1, 1)).sort_values(ascending=False)
missing_data = pd.concat([total, percent_2], axis=1, keys=['Total', '%'])
missing_data

# %%
train_df = train_df.bfill().ffill()
test_df = test_df.bfill().ffill()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## - Lags Features

# %%
def LAG(data,LagFeature,shift=1,NewFeatures=[]) :
    data[NewFeatures[0]]   = data[LagFeature]  - data[LagFeature].shift(shift)
    data[NewFeatures[1]]   = data[LagFeature].shift(shift)

num_feats = train_df.columns
num_feats = num_feats.drop(['Week','DayOfYear','DayOfWeek','Year','Month','Day','pm2_5','temp_mean','humidity','site_longitude','site_latitude','device'])

for feature in num_feats:
    LAG(train_df,LagFeature=f'{feature}',shift=1,NewFeatures=[f'{feature}_diff_Lag1',f'{feature}_Lag1'])
    LAG(test_df,LagFeature=f'{feature}',shift=1,NewFeatures=[f'{feature}_diff_Lag1',f'{feature}_Lag1'])

# %% [markdown]
# ## - Combination Between Time Features

# %%
for dataset in (train_df,test_df):
    dataset['Year_Month'] = dataset['Year'].astype(str) + '-' + dataset['Month'].astype(str)
    dataset['Year_Week'] = dataset['Year'].astype(str) + '-' + dataset['Week'].astype(str)
    dataset['Year_Month_Day'] = dataset['Year'].astype(str) + '-' + dataset['Month'].astype(str) + '-' + dataset['Day'].astype(str)
    
feats = ['Year_Month','Year_Week','Year_Month_Day']
train_df,test_df = label_enc(train_df,test_df,feats)
# Out:
# Year_Month
# Year_Week
# Year_Month_Day

# %% [markdown]
# ## - Aggregations Features

# %%
DevicePM2_5Mean = dict(train_df.groupby('device')['pm2_5'].mean())
DevicePM2_5Std = dict(train_df.groupby('device')['pm2_5'].std())
DevicePM2_5Min = dict(train_df.groupby('device')['pm2_5'].min())
DevicePM2_5Max = dict(train_df.groupby('device')['pm2_5'].max())

for dataset in (train_df,test_df):
    dataset['DevicePM2_5Mean'] = dataset['device'].map(DevicePM2_5Mean)
    dataset['DevicePM2_5Std'] = dataset['device'].map(DevicePM2_5Std)
    dataset['DevicePM2_5Min'] = dataset['device'].map(DevicePM2_5Min)
    dataset['DevicePM2_5Max'] = dataset['device'].map(DevicePM2_5Max)

# %%
def Agg(Feature):
    for dataset in (train_df,test_df):
        dataset[f'{Feature}PerMonth'] = dataset['Month'].map(dict(dataset.groupby('Month')[Feature].mean()))
        dataset[f'{Feature}PerWeek'] = dataset['Year_Week'].map(dict(dataset.groupby('Year_Week')[Feature].mean()))
        dataset[f'{Feature}PerDay'] = dataset['Year_Month_Day'].map(dict(dataset.groupby('Year_Month_Day')[Feature].mean()))
        
        dataset[f'{Feature}Month_std'] = dataset['Month'].map(dict(dataset.groupby('Month')[Feature].std()))
        dataset[f'{Feature}Week_std'] = dataset['Year_Week'].map(dict(dataset.groupby('Year_Week')[Feature].std()))
        dataset[f'{Feature}Day_std'] = dataset['Year_Month_Day'].map(dict(dataset.groupby('Year_Month_Day')[Feature].std()))
        
        dataset[f'{Feature}Month_min'] = dataset['Month'].map(dict(dataset.groupby('Month')[Feature].min()))
        dataset[f'{Feature}Week_min'] = dataset['Year_Week'].map(dict(dataset.groupby('Year_Week')[Feature].min()))
        dataset[f'{Feature}Day_min'] = dataset['Year_Month_Day'].map(dict(dataset.groupby('Year_Month_Day')[Feature].min()))
       
        dataset[f'{Feature}Month_max'] = dataset['Month'].map(dict(dataset.groupby('Month')[Feature].max()))
        dataset[f'{Feature}Week_max'] = dataset['Year_Week'].map(dict(dataset.groupby('Year_Week')[Feature].max()))
        dataset[f'{Feature}Day_max'] = dataset['Year_Month_Day'].map(dict(dataset.groupby('Year_Month_Day')[Feature].max()))
        
Agg('temp_mean')
Agg('humidity')

# %%
train_df.drop(['Year_Month','Year_Week','Year_Month_Day'],inplace=True,axis=1)
test_df.drop(['Year_Month','Year_Week','Year_Month_Day'],inplace=True,axis=1)

# %% [markdown]
# ## - Rolling Features

# %%
def Rolling(feature):
    for dataset in (train_df,test_df):
        dataset[f'{feature}_Rolling_3'] = dataset[feature].rolling(3).mean()
        dataset[f'{feature}_Rolling_5'] = dataset[feature].rolling(5).mean()

        dataset[f"{feature}_rolling_mean_60"] = dataset.rolling(60).mean()[feature]
        dataset[f"{feature}_rolling_max_60"] = dataset.rolling(60).max()[feature]
        dataset[f"{feature}_rolling_min_60"] = dataset.rolling(60).min()[feature]

        dataset[f"{feature}_rolling_mean_30"] = dataset.rolling(30).mean()[feature]
        dataset[f"{feature}_rolling_max_30"] = dataset.rolling(30).max()[feature]
        dataset[f"{feature}_rolling_min_30"] = dataset.rolling(30).min()[feature]

        dataset[f"{feature}_rolling_mean_10"] = dataset.rolling(10).mean()[feature]
        dataset[f"{feature}_rolling_max_10"] = dataset.rolling(10).max()[feature]
        dataset[f"{feature}_rolling_min_10"] = dataset.rolling(10).min()[feature]

Rolling('temp_mean')
Rolling('humidity')

# %% [markdown]
# ## - Polar Coordinates

# %%
def Polar(X,y, a = 0, b = 0): # a and b represnt the center
    r = np.sqrt((X-a)**2 + (y-b)**2)
    phi = np.arctan2((y-a), (X-b))
    return r, phi

train_df['R'], train_df['Phi'] = Polar(train_df["site_latitude"],train_df["site_longitude"])
test_df['R'], test_df['Phi'] = Polar(test_df["site_latitude"],test_df["site_longitude"])

# %% [markdown]
# ## - Foureier Frequnecies and Amplitudes For Features That Contain Seasonality

# %%
freq2_dict_no_log = dict()
freq3_dict_no_log = dict()

amp2_dict_no_log = dict()
amp3_dict_no_log = dict()

for feat_1 in ('Year','Month','Day'):
    for feat_2 in ('temp_mean', 'humidity'):
        for i in range(min(train_df[feat_1].unique()), max(train_df[feat_1].unique()) + 1):

            a = train_df.loc[train_df[feat_1]==i]
            a_sales = a[feat_2]

            Y = np.fft.fft(a_sales.values)
            Y = abs(Y)
            freq = np.fft.fftfreq(len(Y), 1)

            intercept_index = np.argmax(Y)
            Y = np.delete(Y, intercept_index)
            freq = np.delete(freq, intercept_index)

            amplitude_1_index = np.argmax(Y)
            amplitude_1 = Y[amplitude_1_index]
            Y = np.delete(Y, amplitude_1_index)
            freq_1 = freq[amplitude_1_index]
            freq = np.delete(freq, amplitude_1_index)

            amplitude_2_index = np.argmax(Y)
            amplitude_2 = Y[amplitude_2_index]
            Y = np.delete(Y, amplitude_2_index)
            freq_2 = freq[amplitude_2_index]
            freq = np.delete(freq, amplitude_2_index)

            amplitude_3_index = np.argmax(Y)
            amplitude_3 = Y[amplitude_3_index]
            Y = np.delete(Y, amplitude_3_index)
            freq_3 = freq[amplitude_3_index]
            freq = np.delete(freq, amplitude_3_index)

            #Freq_1 is not included because it seems as it is always 0
            a[f'Frequency_2_{feat_1}_{feat_2}'] = freq_2
            a[f'Frequency_3_{feat_1}_{feat_2}'] = freq_3

            a[f'Amplitude_2_{feat_1}_{feat_2}'] = amplitude_2
            a[f'Amplitude_3_{feat_1}_{feat_2}'] = amplitude_3


            freq2_dict_no_log[i] = freq_2
            freq3_dict_no_log[i] = freq_3

            amp2_dict_no_log[i] = amplitude_2
            amp3_dict_no_log[i] = amplitude_3


            if i == min(train_df[feat_1].unique()):
                k = a
            else:
                k = pd.concat([k,a])
                
        train_df = k
        
        test_df[f'Frequency_2_{feat_1}_{feat_2}'] = test_df[feat_1].map(freq2_dict_no_log)
        test_df[f'Frequency_3_{feat_1}_{feat_2}'] = test_df[feat_1].map(freq3_dict_no_log)
        test_df[f'Amplitude_2_{feat_1}_{feat_2}'] = test_df[feat_1].map(amp2_dict_no_log)
        test_df[f'Amplitude_3_{feat_1}_{feat_2}'] = test_df[feat_1].map(amp3_dict_no_log)
        
        freq2_dict_no_log = dict()
        freq3_dict_no_log = dict()
        amp2_dict_no_log = dict()
        amp3_dict_no_log = dict()

# %% [markdown]
# ## - Percentage change in Temperature and Humidity

# %%
periods = [1, 3, 7, 14]
for period in periods:
    train_df.loc[:, f"PctChangeTemp_{period}"] = train_df["temp_mean"].pct_change(period)
    train_df.loc[:, f"PctChangeHumi_{period}"] = train_df["humidity"].pct_change(period)
    test_df.loc[:, f"PctChangeTemp_{period}"] = test_df["temp_mean"].pct_change(period)
    test_df.loc[:, f"PctChangeHumi_{period}"] = test_df["humidity"].pct_change(period)

# %% [markdown]
# ## - Historic Volatility

# %%
periods = [3, 7, 14]
for period in periods:
    train_df.loc[:, f"volatility_temp_mean_{period}"] = train_df["temp_mean"].diff().rolling(period).std()
    test_df.loc[:, f"volatility_temp_mean_{period}"] = test_df["temp_mean"].diff().rolling(period).std()
    train_df.loc[:, f"volatility_humidity_{period}"] = train_df["humidity"].diff().rolling(period).std()
    test_df.loc[:, f"volatility_humidity_{period}"] = test_df["humidity"].diff().rolling(period).std()

# %% [markdown]
# # Encoding

# %%
train_df, test_df = label_enc(train_df,test_df,['device'])
# Out:
# device

# %% [markdown]
# ## Sort The Data For Correct Validation

# %%
temp = train_df.sort_values(['date','device']).copy()
temp['date'] = temp.index
temp = temp.reset_index(drop=True)

# %%
train_df = train_df.sort_values(['date','device']).reset_index(drop=True) 
test_df = test_df.sort_values(['date','device']).reset_index(drop=True)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Validation

# %%
params = {'objective':'RMSE','n_estimators': 2064, 'learning_rate': 0.03196897706232692, 
          'depth': 5, 'reg_lambda': 12.680808984686983}
CB = CatBoostRegressor(**params,verbose=0, random_state=42, task_type = 'CPU')
LogCB = TransformedTargetRegressor(CB, func = np.log1p, inverse_func = np.expm1)

# %%
print('Validating...')

X = train_df.drop('pm2_5',axis=1).values
y = train_df['pm2_5'].values

scores = []
for train_index, test_index in GroupTimeSeriesSplit(n_splits=4).split(X, y, groups=temp['date'].values):
    print(f'====Train On {len(train_index)} Samples ====Validate On {len(test_index)} Sapmles====')
    print(f'Train On Months [{temp.reset_index(drop=True).loc[train_index].date.min()} - {temp.reset_index(drop=True).loc[train_index].date.max()}]')
    print(f'Validate On Months [{temp.reset_index(drop=True).loc[test_index].date.min()} - {temp.reset_index(drop=True).loc[test_index].date.max()}]')
    X_Train, X_Test = X[train_index], X[test_index]
    y_Train, y_Test = y[train_index], y[test_index]
    LogCB.fit(X_Train,y_Train)
    vali = temp.loc[(temp.index >= test_index[0]) & (temp.index <= test_index[-1])]
    y_pred = LogCB.predict(X_Test)
    scores.append(mean_absolute_error(y_pred,y_Test))
    print(scores[-1])
    
#RMSE as Loss, CPU, Used TransformedTargetRegressor
# Fold 1: 18.316379697884738
# Fold 2: 18.14936480700997
# Fold 3: 15.91820261813899
# Fold 4: 12.967791513084244
# Out:
# Validating...
# ====Train On 202 Samples ====Validate On 806 Sapmles====
# Train On Months [2019-03-14 00:00:00 - 2019-06-27 00:00:00]
# Validate On Months [2019-06-28 00:00:00 - 2019-10-10 00:00:00]
# 18.316379697884738
# ====Train On 1008 Samples ====Validate On 2658 Sapmles====
# Train On Months [2019-03-14 00:00:00 - 2019-10-10 00:00:00]
# Validate On Months [2019-10-11 00:00:00 - 2020-01-23 00:00:00]
# 18.14936480700997
# ====Train On 3666 Samples ====Validate On 2966 Sapmles====
# Train On Months [2019-03-14 00:00:00 - 2020-01-23 00:00:00]
# Validate On Months [2020-01-24 00:00:00 - 2020-05-07 00:00:00]
# 15.91820261813899
# ====Train On 6632 Samples ====Validate On 3291 Sapmles====
# Train On Months [2019-03-14 00:00:00 - 2020-05-07 00:00:00]
# Validate On Months [2020-05-08 00:00:00 - 2020-08-20 00:00:00]
# 12.967791513084244

# %%
plotImp(LogCB,train_df.drop('pm2_5',axis=1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-892e78a772ee> in <module>
# ----> 1 plotImp(LogCB,train_df.drop('pm2_5',axis=1))
#
# <ipython-input-55-1e84abc6e9e8> in plotImp(model, X, num, fig_size)
#       1 #Plot the Features Importances
#       2 def plotImp(model, X , num = 30, fig_size = (60, 30)):
# ----> 3     feature_imp = pd.DataFrame({'Value':model.feature_importances_,'Feature':X.columns})
#       4     plt.figure(figsize=fig_size)
#       5     sns.set(font_scale = 5)
#
# AttributeError: 'TransformedTargetRegressor' object has no attribute 'feature_importances_'

# %% [markdown]
# ## Inference

# %%
#Averaging the predictions of the same model with different seeds to get more consistent results
X = train_df.drop('pm2_5',axis=1)
y = train_df['pm2_5']

Predictions = pd.DataFrame()

for seed in range(20,46):
    print(f'Seed: {seed}')
    params = {'objective':'MAE','n_estimators': 2064, 'learning_rate': 0.03196897706232692, 'depth': 5, 'reg_lambda': 12.680808984686983}
    CB = CatBoostRegressor(**params,verbose=0, random_state=seed, task_type = 'CPU')
    LogCB = TransformedTargetRegressor(CB, func = np.log1p, inverse_func = np.expm1)  
    LogCB.fit(X, y)

    Predictions[f'Target_{seed}'] = LogCB.predict(test_df)
    Predictions[f'Target_{seed}'] = Predictions[f'Target_{seed}'] * 0.975  #A Correction Factor of 0.975
    
#Averaging the Results
Predictions['Mean'] = Predictions.mean(axis=1)
Predictions['HMean'] = Predictions.apply(stats.hmean, axis=1)
Predictions['GMean'] = Predictions.apply(stats.gmean, axis=1)

#Averaging the Second Results
FinalPred = Predictions[['Mean','HMean','GMean']].apply(stats.hmean,axis=1)

#Making the submission file
submission = pd.DataFrame({"Id": ID ,"pm2_5": FinalPred.values})
submission.to_csv('AirQualityPrediction.csv',index=False)
# Out:
# Seed: 20
# Seed: 21
# Seed: 22
# Seed: 23
# Seed: 24
# Seed: 25
# Seed: 26
# Seed: 27
# Seed: 28
# Seed: 29
# Seed: 30
# Seed: 31
# Seed: 32
# Seed: 33
# Seed: 34
# Seed: 35
# Seed: 36
# Seed: 37
# Seed: 38
# Seed: 39
# Seed: 40
# Seed: 41
# Seed: 42
# Seed: 43
# Seed: 44
# Seed: 45
